# %% [markdown]
# <a href="https://colab.research.google.com/github/KamiSir/FlyRank-internship-tasks/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/KamiSir/FlyRank-internship-tasks/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
# I am choosing the "Content Decay / Refresh Prioritization" lane. Since our provided dataset focuses on search performance, this approach lets us build a practical model to identify which specific pages are actively losing organic traffic and need immediate attention from the content team.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# No calculation needed for this section.
import pandas as pd

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# The Decision: Which specific URLs should be prioritized for a content update or rewrite this week?
#
# The Action: A content writer or SEO manager spends 4-5 hours rewriting and optimizing the flagged page.
#
# The Cost: A false positive wastes hours of a writer's time on a page that was already performing fine. A false negative means a truly declining page goes unnoticed, resulting in a permanent loss of search traffic and revenue.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# No calculation needed for this section.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# Here is a quick snapshot of the local starter dataset to validate its size and structure before we build the pipeline.

# %%
import pandas as pd

# Load the starter dataset directly from the public GitHub repo
url = 'https://raw.githubusercontent.com/flyrank-bih/flyrank-ml-internship-starter/main/data/raw/content_refresh_anonymized.csv'
df = pd.read_csv(url)

print(f"Total records (rows) to analyze: {len(df):,}")
print(f"Total features (columns) available: {len(df.columns)}")
print(f"Sample of the dataset shape: {df.shape}")
# Out:
# Total records (rows) to analyze: 30,000
# Total features (columns) available: 44
# Sample of the dataset shape: (30000, 44)

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# What I can claim: I can provide observed, directional, and decision-support scores that flag which pages share data characteristics with historically decaying content.
#
# What I cannot claim: I cannot claim absolute causal proof of why traffic dropped (e.g., proving a specific Google algorithm update caused it), nor can I predict exactly how the search engine will rank the page in the future.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# No calculation needed for this section.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [x ] Every section above is filled — markdown thinking AND the code that backs it
# - [ x] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [x ] No client names, URLs, or private queries anywhere
# - [x ] My claims use careful words: observed, measured, directional, decision-support
# - [x ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
