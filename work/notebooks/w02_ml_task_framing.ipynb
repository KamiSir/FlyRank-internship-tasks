# %% [markdown]
# <a href="https://colab.research.google.com/github/KamiSir/FlyRank-internship-tasks/blob/main/work/notebooks/w02_ml_task_framing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/flyrank-bih/flyrank-ml-internship-starter/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# I am framing this as a Classification (specifically, binary classification) and Scoring task. We want to output a probability score between 0 and 1 that represents the risk of a page decaying, and classify pages above a certain threshold as "needs refresh."

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# No code needed for this conceptual section.

# %% [markdown]
# ## 2. Target or proxy
#
# The Target: A binary label (e.g., is_decaying), where 1 means the page has significantly lost traffic and 0 means it is stable.
#
# Where it comes from: This will be a calculated rule based on historical data (e.g., if traffic dropped by more than 15% over the last 3 months compared to the previous 3 months). It is a proxy because a traffic drop does not flawlessly prove the content is "bad", but it strongly correlates with a need for an update.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# No code needed for this conceptual section.

# %% [markdown]
# ## 3. Success metric
#
# Our primary success metric will be Precision. Because a writer's time is expensive, we want to minimize false positives. If the model flags a page for a 5-hour rewrite, we need to be highly confident that the page is actually decaying.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# No code needed for this conceptual section.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# The unit of analysis is a single web page. One row = one unique URL with its associated performance metrics over a specific timeframe.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd

# Load the starter dataset directly from the public GitHub repo
url = 'https://raw.githubusercontent.com/flyrank-bih/flyrank-ml-internship-starter/main/data/raw/content_refresh_anonymized.csv'
df = pd.read_csv(url)

# Show what a single row represents (the unit of analysis)
print("One row represents one URL. Here is a single record:")
display(df.head(1))
# Out:
# One row represents one URL. Here is a single record:
#              content_id          client_id  search_volume  competition  \
# 0  content_304f48230142  client_f369cb89fc           10.0         0.67
#
#   competition_level   cpc     content_type    main_intent  word_count  \
# 0              HIGH  2.05  keyword article  transactional      3221.0
#
#    char_count  ... char_count_tier   ctr  avg_position  engagement_rate  \
# 0     20457.0  ...     15000-25000  0.76          10.6             5.88
#
#    scroll_rate  ai_traffic_pct  impression_tier  position_tier  \
# 0         4.55             0.0             good       striking
#
#    trend_direction  trend_pct
# 0             down      -41.4
#
# [1 rows x 44 columns]

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# A fixed rule like IF traffic_drop > 15% THEN refresh is too brittle. Traffic naturally fluctuates due to seasonality, holidays, or temporary technical glitches. ML can weigh multiple competing factors simultaneously (e.g., CTR changes, impression volume, historical volatility, and seasonality) to distinguish true content decay from normal variance.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# No code needed for this conceptual section.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [x ] Every section above is filled — markdown thinking AND the code that backs it
# - [x ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [x ] No client names, URLs, or private queries anywhere
# - [x ] My claims use careful words: observed, measured, directional, decision-support
# - [x ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
